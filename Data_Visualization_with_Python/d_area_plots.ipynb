# %%
import pandas as pd
import numpy as np

# %%
#El gráfico de tramas también es conocido como gráfico de área 
#Sirve para representar totales acumulados o porcentajes
filename='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Canada.xlsx' 
df_can=pd.read_excel( filename, sheet_name="Canada by Citizenship", skiprows=range(20), skipfooter=2 )

df_can.head()
# Out:
#          Type    Coverage          OdName  AREA  ...  2010  2011  2012  2013
# 0  Immigrants  Foreigners     Afghanistan   935  ...  1758  2203  2635  2004
# 1  Immigrants  Foreigners         Albania   908  ...   561   539   620   603
# 2  Immigrants  Foreigners         Algeria   903  ...  4752  4325  3774  4331
# 3  Immigrants  Foreigners  American Samoa   909  ...     0     0     0     0
# 4  Immigrants  Foreigners         Andorra   908  ...     0     0     1     1
#
# [5 rows x 43 columns]

# %%
df_can.rename(columns={"OdName":"Country"},inplace=True)
df_can.set_index("Country",inplace=True)

# %%
df_can["Total"]=df_can[1980]+df_can[1981]+df_can[1982]+df_can[1983]+df_can[1984]+df_can[1985]+df_can[1986]+df_can[1987]+df_can[1988]+df_can[1989]+df_can[1990]+df_can[1991]+df_can[1992]+df_can[1993]+df_can[1994]+df_can[1995]+df_can[1996]+df_can[1997]+df_can[1998]+df_can[1999]+df_can[2000]+df_can[2001]+df_can[2002]+df_can[2003]+df_can[2004]+df_can[2005]+df_can[2006]+df_can[2007]+df_can[2008]+df_can[2009]+df_can[2010]+df_can[2011]+df_can[2012]+df_can[2013]
df_can.head()
# Out:
#                       Type    Coverage  AREA AreaName  ...  2011  2012  2013  Total
# Country                                                ...
# Afghanistan     Immigrants  Foreigners   935     Asia  ...  2203  2635  2004  58639
# Albania         Immigrants  Foreigners   908   Europe  ...   539   620   603  15699
# Algeria         Immigrants  Foreigners   903   Africa  ...  4325  3774  4331  69439
# American Samoa  Immigrants  Foreigners   909  Oceania  ...     0     0     0      6
# Andorra         Immigrants  Foreigners   908   Europe  ...     0     1     1     15
#
# [5 rows x 43 columns]

# %%
#Ordenamos el dataset
df_can.sort_values(['Total'],ascending=False,axis=0,inplace=True)
df_can.head()
# Out:
#                                                           Type  ...   Total
# Country                                                         ...
# India                                               Immigrants  ...  691904
# China                                               Immigrants  ...  659962
# United Kingdom of Great Britain and Northern Ir...  Immigrants  ...  551500
# Philippines                                         Immigrants  ...  511391
# Pakistan                                            Immigrants  ...  241600
#
# [5 rows x 43 columns]

# %%
#Creamos el listado de años
years=list(range(1980,2014))

#Agarramos el top 5
df_top5=df_can.head()
df_top5=df_top5[years].transpose()
df_top5
# Out:
# Country  India  China  ...  Philippines  Pakistan
# 1980      8880   5123  ...         6051       978
# 1981      8670   6682  ...         5921       972
# 1982      8147   3308  ...         5249      1201
# 1983      7338   1863  ...         4562       900
# 1984      5704   1527  ...         3801       668
# 1985      4211   1816  ...         3150       514
# 1986      7150   1960  ...         4166       691
# 1987     10189   2643  ...         7360      1072
# 1988     11522   2758  ...         8639      1334
# 1989     10343   4323  ...        11865      2261
# 1990     12041   8076  ...        12509      2470
# 1991     13734  14255  ...        12718      3079
# 1992     13673  10846  ...        13670      4071
# 1993     21496   9817  ...        20479      4777
# 1994     18620  13128  ...        19532      4666
# 1995     18489  14398  ...        15864      4994
# 1996     23859  19415  ...        13692      9125
# 1997     22268  20475  ...        11549     13073
# ...

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df_top5.plot(kind='area')
plt.title("Top 5 países inmigración")
plt.ylabel("Número de inmigrantes")
plt.xlabel("Años")

plt.show()
