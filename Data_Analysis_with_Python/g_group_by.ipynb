# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.DataFrame()
df["drive-wheels"] = None
df["body-style"]=None
df["price"]=None
drive=["4wd","4wd","4wd","fwd","fwd","fwd","fwd","fwd","rwd","rwd","rwd","rwd","rwd"]

body=["hatchback","sedan","wagon","convertible","hardtop","hatchback","sedan","wagon","convertible","hardtop","hatchback","sedan","wagon"]

price=[7603,12647,9095,11595,8249,8396,9611,9997,23949,24202,14337,21711,16994]

df["drive-wheels"]=drive
df["body-style"]=body
df["price"]=price


df
# Out:
#    drive-wheels   body-style  price
# 0           4wd    hatchback   7603
# 1           4wd        sedan  12647
# 2           4wd        wagon   9095
# 3           fwd  convertible  11595
# 4           fwd      hardtop   8249
# 5           fwd    hatchback   8396
# 6           fwd        sedan   9611
# 7           fwd        wagon   9997
# 8           rwd  convertible  23949
# 9           rwd      hardtop  24202
# 10          rwd    hatchback  14337
# 11          rwd        sedan  21711
# 12          rwd        wagon  16994

# %%
#para agrupar hacemos
df_agrupado=df.groupby(['drive-wheels'],as_index=False).mean()
df_agrupado
# Out:
#   drive-wheels         price
# 0          4wd   9781.666667
# 1          fwd   9569.600000
# 2          rwd  20238.600000

# %%
#También podemos hacer una tabla pivotante
df_pivot=df.pivot(index="drive-wheels",columns="body-style")
df_pivot
# Out:
#                    price
# body-style   convertible  hardtop hatchback    sedan    wagon
# drive-wheels
# 4wd                  NaN      NaN    7603.0  12647.0   9095.0
# fwd              11595.0   8249.0    8396.0   9611.0   9997.0
# rwd              23949.0  24202.0   14337.0  21711.0  16994.0

# %%
#Otra  manera de representar una tabla pivotante, es con mapas de calor
plt.pcolor(df_pivot, cmap='RdBu')
plt.colorbar()
plt.show()
