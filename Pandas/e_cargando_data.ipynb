# %%
import pandas as pd

# %%
csv_path='archivos/archivo.csv'
data = pd.read_csv(csv_path)

# %%
#con head podemos ver los primeros 5 registros del dataframe
data.head()
# Out:
#      fecha      motivo        salido_de      ingresado_a provincia_origen  \
# 0  2013-01  Exposicion  Establecimiento     Remate feria           Chubut
# 1  2013-01   Invernada  Establecimiento     Remate feria     Buenos Aires
# 2  2013-01     Replume  Establecimiento  Establecimiento       Entre Rios
# 3  2013-01       Faena  Establecimiento      Frigorifico         Santa Fe
# 4  2013-01       Faena  Establecimiento      Frigorifico     Buenos Aires
#
#    provincia_origen_id departamento_origen  departamento_origen_id  \
# 0                   26           Futaleufu                   26035
# 1                    6          9 de Julio                    6588
# 2                   30              Parana                   30084
# 3                   82         San Lorenzo                   82119
# 4                    6            Canuelas                    6134
#
#   provincia_destino  provincia_destino_id  ... reproductores  \
# ...

# %%
#Para cargar Excels
xlsx_path ='archivos/archivoExcel.xlsx'
data=pd.read_excel(xlsx_path)
data.head()
# Out:
#    OrderDate   Region      Rep    Item  Units  Unit Cost   Total
# 0 2019-01-06     East    Jones  Pencil     95       1.99  189.05
# 1 2019-01-23  Central   Kivell  Binder     50      19.99  999.50
# 2 2019-02-09  Central  Jardine  Pencil     36       4.99  179.64
# 3 2019-02-26  Central     Gill     Pen     27      19.99  539.73
# 4 2019-03-15     West  Sorvino  Pencil     56       2.99  167.44

# %%
#podemos crear un dataframe
songs={
        'Album':['Thriller','Back in black','The Dark Side of the Moon',\
               'The BodyGuard','Bat out of Hell'],
      'Released':[1982,1980,1973,1992,1977],
       'Length':['00:42:19','00:42:11','00:42:49','00:57:44','00:46:33']      
      }

# %%
#para pasarlo a data Frame usamos el método de Pandas DataFrame
songs_frame=pd.DataFrame(songs)

# %%
#Podemos crear otro dataFrame a partir de una columna de otro Df.
x=songs_frame[['Length']]

# %%
print(x)
# Out:
#      Length
# 0  00:42:19
# 1  00:42:11
# 2  00:42:49
# 3  00:57:44
# 4  00:46:33

# %%
#También se puede hacer con múltiples columnas
y=songs_frame[['Album','Released']]
print(y)
# Out:
#                        Album  Released
# 0                   Thriller      1982
# 1              Back in black      1980
# 2  The Dark Side of the Moon      1973
# 3              The BodyGuard      1992
# 4            Bat out of Hell      1977
